# %% [markdown]
# # Visualize a Qubit

# %%
from qiskit.visualization import plot_bloch_vector
# %matplotlib inline

# Coordinates for the |0> state
state_0 = [0, 0, 1]

# Plotting the Bloch vector
plot_bloch_vector(state_0, title="Bloch Sphere Representation of |0>")

# %%
from qiskit.visualization import plot_bloch_vector
# %matplotlib inline

# Coordinates for the |0> state
state_0 = [0, 0, -1]

# Plotting the Bloch vector
plot_bloch_vector(state_0, title="Bloch Sphere Representation of |1>")

# %%
# Parameters
theta = np.pi/2  # Example value for theta [0, pi]
phi = np.pi / 4    # Example value for phi [0, 2*pi]

# State vector for the qubit
psi = [
    np.cos(theta / 2),
    np.exp(1j * phi) * np.sin(theta / 2)
]

# plot psi on block sphere
plot_bloch_multivector(psi)

# %%
# import qiskit
# from qiskit import QuantumCircuit, Aer, execute
# from qiskit.visualization import plot_bloch_multivector
# import numpy as np

# # Parameters
# theta = np.pi/2  # Example value for theta [0, pi]
# phi = np.pi / 4    # Example value for phi [0, 2*pi]

# # State vector for the qubit
# psi = [
#     np.cos(theta / 2),
#     np.exp(1j * phi) * np.sin(theta / 2)
# ]

# # Create a quantum circuit with one qubit
# qc = QuantumCircuit(1)

# # Initialize the qubit to the state psi
# qc.initialize(psi, 0)

# # Use the statevector simulator to get the final state
# simulator = Aer.get_backend('statevector_simulator')
# result = execute(qc, simulator).result()
# statevector = result.get_statevector()

# # Visualize the qubit state on the Bloch sphere
# plot_bloch_multivector(statevector)

# %% [markdown]
# # Create a circuit

# %%
qc = QuantumCircuit(2)
qc.draw("mpl")

# %%
# Use the statevector simulator to get the final state
simulator = Aer.get_backend('statevector_simulator') 
result = execute(qc, simulator).result()
statevector = result.get_statevector()

# Visualize the qubit state on the Bloch sphere
plot_bloch_multivector(statevector)

# %%
# qc.initialize(psi, 0)
# qc.draw("mpl")

# %%
# # Use the statevector simulator to get the final state
# simulator = Aer.get_backend('statevector_simulator') 
# result = execute(qc, simulator).result()
# statevector = result.get_statevector()

# # Visualize the qubit state on the Bloch sphere
# plot_bloch_multivector(statevector)

# %%
qc = QuantumCircuit(2) # Create a quantum circuit with two qubits
qc.h(0) # Apply a Hadamard gate to the first qubit
qc.draw("mpl") # Draw the circuit

# %%
# Use the statevector simulator to get the final state
simulator = Aer.get_backend('statevector_simulator') 
result = execute(qc, simulator).result()
statevector = result.get_statevector()

# Visualize the qubit state on the Bloch sphere
plot_bloch_multivector(statevector)

# %%
from qiskit import QuantumCircuit, Aer, execute
from qiskit.visualization import plot_bloch_multivector
import matplotlib.pyplot as plt

# Create a 3-qubit quantum circuit
qc = QuantumCircuit(4)

# Apply Pauli gates
qc.x(1)  # Pauli-X on the first qubit
qc.y(2)  # Pauli-Y on the second qubit
qc.z(3)  # Pauli-Z on the third qubit

# Use the statevector simulator
simulator = Aer.get_backend('statevector_simulator')
result = execute(qc, simulator).result()
statevector = result.get_statevector()

qc.draw("mpl")

# %%
# Visualize the qubit states on the Bloch spheres
plot_bloch_multivector(statevector)

# %%
from qiskit import QuantumCircuit, Aer, execute
from qiskit.visualization import plot_bloch_multivector
import matplotlib.pyplot as plt

# Parameters
theta = np.pi/3  # Example value for theta [0, pi]
phi = np.pi /2    # Example value for phi [0, 2*pi]

# State vector for the qubit
psi = [
    np.cos(theta / 2),
    np.exp(1j * phi) * np.sin(theta / 2)
]
print(psi)

# plot psi on block sphere
plot_bloch_multivector(psi)

# Create a 3-qubit quantum circuit
qc = QuantumCircuit(4)

qc.initialize(psi, 0)
qc.initialize(psi, 1)
qc.initialize(psi, 2)
qc.initialize(psi, 3)


# Apply Pauli gates
qc.x(1)  # Pauli-X on the first qubit
qc.y(2)  # Pauli-Y on the second qubit
qc.z(3)  # Pauli-Z on the third qubit

# Use the statevector simulator
simulator = Aer.get_backend('statevector_simulator')
result = execute(qc, simulator).result()
statevector = result.get_statevector()

qc.draw("mpl")
# Out:
# [0.8660254037844387, (3.0616169978683824e-17+0.49999999999999994j)]
# /Users/nicolasmartinet/qiskit/lib/python3.9/site-packages/qiskit/visualization/circuit/matplotlib.py:266: FutureWarning: The default matplotlib drawer scheme will be changed to "iqp" in a following release. To silence this warning, specify the current default explicitly as style="clifford", or the new default as style="iqp".
#   self._style, def_font_ratio = load_style(self._style)

# %%
# Visualize the qubit states on the Bloch spheres
plot_bloch_multivector(statevector)

# %%
from qiskit import QuantumCircuit, Aer, execute
from qiskit.visualization import plot_bloch_multivector
import numpy as np
import matplotlib.pyplot as plt

# Parameters
theta = np.pi / 2  # Example value for theta [0, pi]
phi = 0   # Example value for phi [0, 2*pi]

# State vector for the qubit
psi = [
    np.cos(theta / 2),
    np.exp(1j * phi) * np.sin(theta / 2)
]
print(psi)

# plot psi on Bloch sphere
plot_bloch_multivector(psi)

# Create a 4-qubit quantum circuit
qc = QuantumCircuit(3)

# Initialize all qubits to the state psi
qc.initialize(psi, 0)
qc.initialize(psi, 1)
qc.initialize(psi, 2)

# Apply S gate on the second qubit and T gate on the third and fourth qubits
qc.s(1)  # S gate on the second qubit
qc.t(2)  # T gate on the third qubit

qc.draw("mpl")
# Out:
# [0.7071067811865476, (0.7071067811865475+0j)]

# %%
# Use the statevector simulator
simulator = Aer.get_backend('statevector_simulator')
result = execute(qc, simulator).result()
statevector = result.get_statevector()

# Visualize the qubit states on the Bloch spheres
plot_bloch_multivector(statevector)

# %%
from qiskit import QuantumCircuit
import matplotlib.pyplot as plt

# Create a quantum circuit with 2 qubits
qc = QuantumCircuit(2)

# Optionally, initialize the control qubit to |1> to see the action of the CNOT gate
# qc.x(0)  # Apply Pauli-X gate to flip the first qubit to |1>

qc.x(0)
#qc.x(1)

# Apply CNOT gate with the first qubit as control and the second as target
qc.cx(0, 1)

# Draw the circuit
qc.draw('mpl')

# %%
# Use the statevector simulator
simulator = Aer.get_backend('statevector_simulator')
result = execute(qc, simulator).result()
statevector = result.get_statevector()

# Visualize the qubit states on the Bloch spheres
plot_bloch_multivector(statevector)

# %%
from qiskit import QuantumCircuit
import matplotlib.pyplot as plt

# Create a quantum circuit with 2 qubits
qc = QuantumCircuit(2)

# Initialize the qubits to demonstrate the Swap gate effectively
qc.x(1)  # Apply Pauli-X gate to the second qubit to set it to |1>

# Apply the Swap gate
qc.swap(0, 1)

# Draw the circuit
qc.draw('mpl')
# Out:
# /Users/nicolasmartinet/qiskit/lib/python3.9/site-packages/qiskit/visualization/circuit/matplotlib.py:266: FutureWarning: The default matplotlib drawer scheme will be changed to "iqp" in a following release. To silence this warning, specify the current default explicitly as style="clifford", or the new default as style="iqp".
#   self._style, def_font_ratio = load_style(self._style)

# %%
# Use the statevector simulator
simulator = Aer.get_backend('statevector_simulator')
result = execute(qc, simulator).result()
statevector = result.get_statevector()

# Visualize the qubit states on the Bloch spheres
plot_bloch_multivector(statevector)

# %%
from qiskit import QuantumCircuit
import matplotlib.pyplot as plt

# Create a quantum circuit with 3 qubits
qc = QuantumCircuit(3)

# Initialize the first two qubits (controls) to |1> to see the Toffoli gate in action
qc.x(0)  # Apply Pauli-X gate to the first qubit
qc.x(1)  # Apply Pauli-X gate to the second qubit

# Apply the Toffoli gate with the first two qubits as controls and the third as the target
qc.ccx(0, 1, 2)

# Draw the circuit
qc.draw('mpl')

# %%
# Use the statevector simulator
simulator = Aer.get_backend('statevector_simulator')
result = execute(qc, simulator).result()
statevector = result.get_statevector()

# Visualize the qubit states on the Bloch spheres
plot_bloch_multivector(statevector)

# %%
from qiskit import QuantumCircuit, transpile
from qiskit_aer import AerSimulator

# Use Aer's AerSimulator
simulator = AerSimulator()

# Create a Quantum Circuit acting on the q register
circuit = QuantumCircuit(2, 2)

# Add a H gate on qubit 0
circuit.h(0)

# Add a CX (CNOT) gate on control qubit 0 and target qubit 1
circuit.cx(0, 1)

# Map the quantum measurement to the classical bits
circuit.measure([0, 1], [0, 1])

# Compile the circuit for the support instruction set (basis_gates)
compiled_circuit = transpile(circuit, simulator)

# Execute the circuit on the aer simulator
job = simulator.run(compiled_circuit, shots=1000)

# Grab results from the job
result = job.result()

# Returns counts
counts = result.get_counts(compiled_circuit)
print("\nTotal count for 00 and 11 are:", counts)

# Draw the circuit
circuit.draw("mpl")
# Out:
# Total count for 00 and 11 are: {'11': 478, '00': 522}
# /Users/nicolasmartinet/qiskit/lib/python3.9/site-packages/qiskit/visualization/circuit/matplotlib.py:266: FutureWarning: The default matplotlib drawer scheme will be changed to "iqp" in a following release. To silence this warning, specify the current default explicitly as style="clifford", or the new default as style="iqp".
#   self._style, def_font_ratio = load_style(self._style)

# %%
# Use Aer's AerSimulator
simulator = AerSimulator()

# Create a Quantum Circuit acting on the q register
circuit = QuantumCircuit(2, 3)

# Draw the circuit
circuit.draw("mpl")

# %%
from qiskit.quantum_info import Statevector

# Set the initial state of the simulator to the ground state using from_int
state = Statevector.from_int(0, 2**3)

# Evolve the state by the quantum circuit
state = state.evolve(circuit)

#draw using latex
state.draw('latex')
# Out:
# $$ |000\rangle$$

# %%
# Importing necessary libraries from Qiskit
from qiskit import QuantumCircuit, Aer, execute
from qiskit.quantum_info import Statevector
from qiskit.visualization import plot_bloch_multivector, plot_histogram

qc = QuantumCircuit(2) # Create a quantum circuit with two qubits
qc.h(0) # Apply a Hadamard gate to the first

print(qc)
#      ┌───┐
# q_0: ┤ H ├
#      └───┘
# q_1: ─────


state = Statevector.from_instruction(qc)
print(state)
plot_bloch_multivector(state)
# Out:
#      ┌───┐
# q_0: ┤ H ├
#      └───┘
# q_1: ─────
#
# Statevector([0.70710678+0.j, 0.70710678+0.j, 0.        +0.j,
#              0.        +0.j],
#             dims=(2, 2))

# %%
qc = QuantumCircuit(2) # Create a quantum circuit with two qubits
qc.h(0) # Apply a Hadamard gate to the first
qc.cx(0,1) # Apply a CNOT gate with control qubit 0 and target qubit 1
print(qc)
#      ┌───┐     
# q_0: ┤ H ├──■──
#      └───┘┌─┴─┐
# q_1: ─────┤ X ├
#           └───┘

state = Statevector.from_instruction(qc)
print(state)
qc.draw("mpl")
# Out:
#      ┌───┐
# q_0: ┤ H ├──■──
#      └───┘┌─┴─┐
# q_1: ─────┤ X ├
#           └───┘
# Statevector([0.70710678+0.j, 0.        +0.j, 0.        +0.j,
#              0.70710678+0.j],
#             dims=(2, 2))
# /Users/nicolasmartinet/qiskit/lib/python3.9/site-packages/qiskit/visualization/circuit/matplotlib.py:266: FutureWarning: The default matplotlib drawer scheme will be changed to "iqp" in a following release. To silence this warning, specify the current default explicitly as style="clifford", or the new default as style="iqp".
#   self._style, def_font_ratio = load_style(self._style)
